# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Countries Population from 1995 to 2020.csv")
print(df)
# Out:
#       Year   Country  Population  Yearly % Change  Yearly Change  \
# 0     2020     China  1439323776             0.39        5540090
# 1     2019     China  1433783686             0.43        6135900
# 2     2018     China  1427647786             0.47        6625995
# 3     2017     China  1421021791             0.49        6972440
# 4     2016     China  1414049351             0.51        7201481
# ...    ...       ...         ...              ...            ...
# 4190  1975  Holy See         728             2.48             17
# 4191  1970  Holy See         644            -5.49            -42
# 4192  1965  Holy See         854            -1.18            -10
# 4193  1960  Holy See         906            -0.04              0
# 4194  1955  Holy See         908             0.00              0
#
#       Migrants (net)  Median Age  Fertility Rate Density (P/Km²)  Urban Pop %  \
# 0          -348399.0        38.4            1.69             153         60.8
# 1          -348399.0        37.0            1.65             153         59.7
# 2          -348399.0        37.0            1.65             152         58.6
# 3          -348399.0        37.0            1.65             151         57.5
# 4          -348399.0        37.0            1.65             151         56.3
# ...              ...         ...             ...             ...          ...
# 4190             NaN         NaN             NaN           1,820          NaN
# 4191             NaN         NaN             NaN           1,610          NaN
# 4192             NaN         NaN             NaN           2,135          NaN
# 4193             NaN         NaN             NaN           2,265          NaN
# 4194             NaN         NaN             NaN           2,270          NaN
#
#       Urban Population  Country's Share of World Pop %  World Population  \
# 0          875075919.0                           18.47        7794798739
# 1          856409297.0                           18.59        7713468100
# 2          837022095.0                           18.71        7631091040
# 3          816957613.0                           18.83        7547858925
# 4          796289491.0                           18.94        7464022049
# ...                ...                             ...               ...
# 4190               NaN                            0.00        4079480606
# 4191               NaN                            0.00        3700437046
# 4192               NaN                            0.00        3339583597
# 4193               NaN                            0.00        3034949748
# 4194               NaN                            0.00        2773019936
#
#       Country Global Rank
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 4190                  235
# 4191                  235
# 4192                  235
# 4193                  235
# 4194                  235
#
# [4195 rows x 14 columns]

# %%
df.head()
# Out:
#    Year Country  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020   China  1439323776             0.39        5540090       -348399.0
# 1  2019   China  1433783686             0.43        6135900       -348399.0
# 2  2018   China  1427647786             0.47        6625995       -348399.0
# 3  2017   China  1421021791             0.49        6972440       -348399.0
# 4  2016   China  1414049351             0.51        7201481       -348399.0
#
#    Median Age  Fertility Rate Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        38.4            1.69             153         60.8       875075919.0
# 1        37.0            1.65             153         59.7       856409297.0
# 2        37.0            1.65             152         58.6       837022095.0
# 3        37.0            1.65             151         57.5       816957613.0
# 4        37.0            1.65             151         56.3       796289491.0
#
#    Country's Share of World Pop %  World Population  Country Global Rank
# 0                           18.47        7794798739                    1
# 1                           18.59        7713468100                    1
# 2                           18.71        7631091040                    1
# 3                           18.83        7547858925                    1
# 4                           18.94        7464022049                    1

# %%
df.shape
# Out:
# (4195, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4195 entries, 0 to 4194
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            4195 non-null   int64
#  1   Country                         4195 non-null   object
#  2   Population                      4195 non-null   int64
#  3   Yearly % Change                 4195 non-null   float64
#  4   Yearly Change                   4195 non-null   int64
#  5   Migrants (net)                  3600 non-null   float64
#  6   Median Age                      3600 non-null   float64
#  7   Fertility Rate                  3600 non-null   float64
#  8   Density (P/Km²)                 4195 non-null   object
#  9   Urban Pop %                     4082 non-null   float64
#  10  Urban Population                4082 non-null   float64
#  11  Country's Share of World Pop %  4195 non-null   float64
#  12  World Population                4195 non-null   int64
#  13  Country Global Rank             4195 non-null   int64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 459.0+ KB

# %%
df.describe()
# Out:
#               Year    Population  Yearly % Change  Yearly Change  \
# count  4195.000000  4.195000e+03      4195.000000   4.195000e+03
# mean   1993.951132  2.443381e+07         1.668927   3.298374e+05
# std      21.685009  1.067417e+08         1.653519   1.334366e+06
# min    1955.000000  6.440000e+02       -12.930000  -6.730240e+05
# 25%    1975.000000  2.800885e+05         0.620000   1.293000e+03
# 50%    1995.000000  3.687898e+06         1.540000   3.895000e+04
# 75%    2016.000000  1.306608e+07         2.600000   2.076195e+05
# max    2020.000000  1.439324e+09        23.300000   2.067648e+07
#
#        Migrants (net)   Median Age  Fertility Rate  Urban Pop %  \
# count    3.600000e+03  3600.000000     3600.000000  4082.000000
# mean     7.430833e+00    25.490278        3.885772    51.067369
# std      1.063210e+05     8.233313        1.987803    25.996685
# min     -1.077397e+06    14.400000        0.850000     0.000000
# 25%     -1.254925e+04    18.500000        2.080000    30.400000
# 50%     -8.755000e+02    22.750000        3.400000    50.900000
# 75%      5.000250e+03    31.600000        5.740000    72.700000
# max      1.771991e+06    48.400000        8.800000   100.000000
#
#        Urban Population  Country's Share of World Pop %  World Population  \
# count      4.082000e+03                     4195.000000      4.195000e+03
# mean       1.203792e+07                        0.428942      5.676982e+09
# std        4.744380e+07                        1.807324      1.732658e+09
# min        0.000000e+00                        0.000000      2.773020e+09
# 25%        1.381082e+05                        0.010000      4.079481e+09
# 50%        1.579878e+06                        0.070000      5.744213e+09
# 75%        6.841242e+06                        0.250000      7.464022e+09
# max        8.750759e+08                       22.700000      7.794799e+09
#
#        Country Global Rank
# count          4195.000000
# mean            117.167342
# std              67.503854
# min               1.000000
# 25%              59.000000
# 50%             117.000000
# 75%             175.000000
# max             235.000000

# %% [markdown]
# # Bar plots

# %%
current_population = df[df['Year'] == 2020][:30]

plt.rcParams['figure.figsize'] = (25, 7)
ax = sns.barplot(x = current_population['Country'][:30], y = current_population['Population'][:30], palette = 'tab10')
ax.set_xlabel(xlabel = 'Countries', fontsize = 10)
ax.set_ylabel(ylabel = 'Population in Billion', fontsize = 10)
ax.set_title(label = 'Population of countries in 2020', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(9,15))
ax = sns.barplot(x="Population", y="Country",
                 data=current_population, palette="tab20c",
                 linewidth = 1)
for i,j in enumerate(current_population["Population"]):
    ax.text(.5, i, j, weight="bold", color = 'black', fontsize =10)
plt.title("Population of countries in 2020")
ax.set_xlabel(xlabel = 'Population in Billion', fontsize = 10)
ax.set_ylabel(ylabel = 'Countries', fontsize = 10)
plt.show()

# %%
population_top5_2020 = df[df['Year'] == 2020][:5]
top_5_countries = population_top5_2020['Country'].unique()
top5_popultion = df[df['Country'].isin(top_5_countries)][['Year', 'Country', 'Population']]
top5_popultion_pivot = top5_popultion.pivot(index='Year', columns='Country', values='Population')
top5_popultion_pivot.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_01dc3_row0_col0, #T_01dc3_row0_col1, #T_01dc3_row0_col2, #T_01dc3_row0_col3, #T_01dc3_row0_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_01dc3_row1_col0, #T_01dc3_row1_col2, #T_01dc3_row2_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_01dc3_row1_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_01dc3_row1_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_01dc3_row1_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_01dc3_row2_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_01dc3_row2_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_01dc3_row2_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_01dc3_row2_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_01dc3_row3_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_01dc3_row3_col1, #T_01dc3_row4_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_01dc3_row3_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_01dc3_row3_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_01dc3_row3_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_01dc3_row4_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_01dc3_row4_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_01dc3_row4_col2 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_01dc3_row4_col4, #T_01dc3_row5_col1 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_01dc3_row5_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_01dc3_row5_col2 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_01dc3_row5_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_01dc3_row5_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_01dc3_row6_col0 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_01dc3_row6_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_01dc3_row6_col2 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_01dc3_row6_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_01dc3_row6_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_01dc3_row7_col0 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_01dc3_row7_col1 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_01dc3_row7_col2 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_01dc3_row7_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_01dc3_row7_col4 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_01dc3_row8_col0, #T_01dc3_row10_col1, #T_01dc3_row10_col2 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_01dc3_row8_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_01dc3_row8_col2 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_01dc3_row8_col3 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_01dc3_row8_col4 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_01dc3_row9_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_01dc3_row9_col1, #T_01dc3_row10_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_01dc3_row9_col2 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_01dc3_row9_col3 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_01dc3_row9_col4 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_01dc3_row10_col0 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_01dc3_row10_col4 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_01dc3_row11_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_01dc3_row11_col1 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_01dc3_row11_col2 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_01dc3_row11_col3 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_01dc3_row11_col4 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_01dc3_row12_col0, #T_01dc3_row14_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_01dc3_row12_col1, #T_01dc3_row14_col3 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_01dc3_row12_col2 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_01dc3_row12_col3 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_01dc3_row12_col4 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_01dc3_row13_col0, #T_01dc3_row15_col1, #T_01dc3_row15_col2 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_01dc3_row13_col1 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_01dc3_row13_col2 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_01dc3_row13_col3 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_01dc3_row13_col4, #T_01dc3_row15_col3 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_01dc3_row14_col0 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_01dc3_row14_col2 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_01dc3_row14_col4 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_01dc3_row15_col0, #T_01dc3_row16_col1, #T_01dc3_row16_col2, #T_01dc3_row16_col4 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_01dc3_row15_col4, #T_01dc3_row16_col3 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_01dc3_row16_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_01dc3_row17_col0, #T_01dc3_row17_col1, #T_01dc3_row17_col2, #T_01dc3_row17_col3, #T_01dc3_row17_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_01dc3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th id="T_01dc3_level0_col0" class="col_heading level0 col0" >China</th>
#       <th id="T_01dc3_level0_col1" class="col_heading level0 col1" >India</th>
#       <th id="T_01dc3_level0_col2" class="col_heading level0 col2" >Indonesia</th>
#       <th id="T_01dc3_level0_col3" class="col_heading level0 col3" >Pakistan</th>
#       <th id="T_01dc3_level0_col4" class="col_heading level0 col4" >United States</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01dc3_level0_row0" class="row_heading level0 row0" >1955</th>
#       <td id="T_01dc3_row0_col0" class="data row0 col0" >612241554</td>
#       <td id="T_01dc3_row0_col1" class="data row0 col1" >409880595</td>
#       <td id="T_01dc3_row0_col2" class="data row0 col2" >77273425</td>
#       <td id="T_01dc3_row0_col3" class="data row0 col3" >40488030</td>
#       <td id="T_01dc3_row0_col4" class="data row0 col4" >171685336</td>
#     </tr>
#     <tr>
#       <th id="T_01dc3_level0_row1" class="row_heading level0 row1" >1960</th>
#       <td id="T_01dc3_row1_col0" class="data row1 col0" >660408056</td>
#       <td id="T_01dc3_row1_col1" class="data row1 col1" >450547679</td>
#       <td id="T_01dc3_row1_col2" class="data row1 col2" >87751068</td>
#       <td id="T_01dc3_row1_col3" class="data row1 col3" >44988690</td>
#       <td id="T_01dc3_row1_col4" class="data row1 col4" >186720571</td>
#     </tr>
#     <tr>
#       <th id="T_01dc3_level0_row2" class="row_heading level0 row2" >1965</th>
#       <td id="T_01dc3_row2_col0" class="data row2 col0" >724218968</td>
#       <td id="T_01dc3_row2_col1" class="data row2 col1" >499123324</td>
#       <td id="T_01dc3_row2_col2" class="data row2 col2" >100267062</td>
#       <td id="T_01dc3_row2_col3" class="data row2 col3" >50917975</td>
#       <td id="T_01dc3_row2_col4" class="data row2 col4" >199733676</td>
#     </tr>
#     <tr>
#       <th id="T_01dc3_level0_row3" class="row_heading level0 row3" >1970</th>
#       <td id="T_01dc3_row3_col0" class="data row3 col0" >827601394</td>
#       <td id="T_01dc3_row3_col1" class="data row3 col1" >555189792</td>
#       <td id="T_01dc3_row3_col2" class="data row3 col2" >114793178</td>
#       <td id="T_01dc3_row3_col3" class="data row3 col3" >58142060</td>
#       <td id="T_01dc3_row3_col4" class="data row3 col4" >209513341</td>
#     </tr>
#     <tr>
#       <th id="T_01dc3_level0_row4" class="row_heading level0 row4" >1975</th>
#       <td id="T_01dc3_row4_col0" class="data row4 col0" >926240885</td>
#       <td id="T_01dc3_row4_col1" class=

# %%
fig,ax = plt.subplots(figsize=(20, 10))
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2})

sns.barplot(x="Year", y="Population", data=top5_popultion, hue='Country')
ax.set_ylabel(ylabel = 'Population in Billion', fontsize = 10)
ax.set_xlabel(xlabel = 'Year', fontsize = 10)
ax.set_title('Top 5 most populated countries in the World')
ax.legend();

# %% [markdown]
# # Line Plot

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(df['Year'], df['Yearly Change'])
plt.title('Yearly Population Change')
plt.xlabel('Year')
plt.ylabel('Population in 10 Million')
plt.show()

# %%
plt.figure()
df.plot("Year", "Population")
plt.xlim(1960, 2020)
plt.show()
